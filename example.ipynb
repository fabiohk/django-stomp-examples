# %% [markdown]
# # Introduction
#
# Hello, world! Thanks for trying to understand how to use the [Django Stomp](https://github.com/juntossomosmais/django-stomp) library! We'll follow some examples that will try to bring to you Django Stomp works and how you can use it for asynchronous communication!
#
# Let's go!

# %% [markdown]
# ## First things first
#
# First of all, our demonstration here will use the [RabbitMQ](https://www.rabbitmq.com/) as its broker and the [STOMP](https://stomp.github.io/) procotol for its communication. We have setup everything on our [repository](https://github.com/fabiohk/django-stomp-examples) so that you can easily start this tutorial following its [README](https://github.com/fabiohk/django-stomp-examples/blob/main/README.md), but if you're not following it for some reason, try to setup it first before you run any code inside this notebook.

# %% [markdown]
# ## And, it begins
#
# If you have everything setup, try to login to the RabbitMQ Dashboard that is listening on port 15672 from your local host.
#
# ![RabbitMQ Dashboard](images/rabbitmq-dash.png)
#
# Use the following credentials:
#
# ```text
# username: guest
# password: guest
# ```
#
# And you are on!
#
# ![RabbitMQ Logged Dashboard](images/rabbitmq-logged-dash.png)

# %% [markdown]
# ## Publishing the first message
#
# We can now start our first interaction with Django-stomp. First, we'll need to create a publisher with a unique name (that is passed as parameter):

# %%
import uuid
from django_stomp.builder import build_publisher

publisher = build_publisher(f"publisher-{uuid.uuid4()}")
# Out:
# INFO     [2021-02-19 21:24:58,727] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-ac2dc810-ef40-4093-9b2f-bafdc1fb8a02'}
# INFO     [2021-02-19 21:24:58,728] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:24:58,730] [MainThread] django_stomp: Use SSL? False. Version: 2

# %% [markdown]
# At this point, we just created a publisher, without any interaction with the broker. As we can see in the `Connection` tab
#
# ![No connections](images/no-connections.png)
#
# Now, we can publish our first message! Let's try to publish to a simple queue named as `/queue/xpto`. For that, we'll need to use it inside the `auto_open_close_connection` context that, as it says, will open the connection and close it after the context is closed.

# %%
import uuid
from django_stomp.builder import build_publisher

publisher = build_publisher(f"publisher-{uuid.uuid4()}")

destination_name = "/queue/xpto"
message_to_publish = {
    "key": "value"
}
with publisher.auto_open_close_connection():
    publisher.send(message_to_publish, destination_name)
# Out:
# INFO     [2021-02-19 21:24:58,751] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-3ed72d81-cef4-440d-88de-f6ad74a4f8c3'}
# INFO     [2021-02-19 21:24:58,753] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:24:58,754] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:24:58,755] [MainThread] django_stomp: It is not open. Starting...
# INFO     [2021-02-19 21:24:59,259] [MainThread] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:24:59,261] [MainThread] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:24:59,263] [MainThread] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:24:59,271] [Thread-4] stomp.py: Starting receiver loop (<Thread(Thread-4, started daemon 123145549148160)>)
# INFO     [2021-02-19 21:24:59,276] [MainThread] stomp.py: Created thread <Thread(Thread-4, started daemon 123145549148160)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:24:59,279] [MainThread] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:24:59,302] [Thread-4] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:24:59,309] [MainThread] django_stomp: Connected
# INFO     [2021-02-19 21:24:59,815] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:24:59,817] [MainThread] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:24:59,824] [Thread-4] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:24:59,827] [Thread-4] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:24:59,828] [MainThread] django_stomp: Disconnected

# %% [markdown]
# We got it!
#
# ![Queue received the message](images/queue-received.png)
# ![Message received](images/received-message.png)

# %% [markdown]
# ## Publishing under transaction
#
# Imagine now that you have to publish a lot of messages to a queue and it **must** send it all or nothing. We can do that under a [STOMP transaction]()! To use it, with Django Stomp, we need to the context `do_inside_transaction`

# %%
import uuid
from django_stomp.builder import build_publisher
from django_stomp.services.producer import auto_open_close_connection
from django_stomp.services.producer import do_inside_transaction

publisher = build_publisher(f"publisher-{uuid.uuid4()}")

message_count = 5
destination_name = "/queue/calopsita"
message_to_publish = {
    "key": "value"
}


with auto_open_close_connection(publisher), do_inside_transaction(publisher):
    for _ in range(message_count):
        publisher.send(message_to_publish, destination_name)
# Out:
# INFO     [2021-02-19 21:24:59,952] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-dbc1c07a-71c8-400b-92e4-b1c5f3a489a8'}
# INFO     [2021-02-19 21:24:59,956] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:24:59,958] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:00,466] [MainThread] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:00,470] [MainThread] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:00,473] [MainThread] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:00,475] [Thread-5] stomp.py: Starting receiver loop (<Thread(Thread-5, started daemon 123145549148160)>)
# INFO     [2021-02-19 21:25:00,477] [MainThread] stomp.py: Created thread <Thread(Thread-5, started daemon 123145549148160)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:00,487] [MainThread] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:00,524] [Thread-5] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:00,561] [MainThread] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,083] [MainThread] stomp.py: Sending frame: 'BEGIN'
# DEBUG    [2021-02-19 21:25:01,084] [MainThread] django_stomp: Created transaction ID: ba7f1c36-d0e8-4a2f-95a3-527f25c4a841
# INFO     [2021-02-19 21:25:01,086] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:01,088] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:01,089] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:01,090] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:01,092] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:01,093] [MainThread] stomp.py: Sending frame: 'COMMIT'
# INFO     [2021-02-19 21:25:01,094] [MainThread] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:01,121] [Thread-5] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:01,123] [Thread-5] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:01,123] [MainThread] django_stomp: Disconnected

# %% [markdown]
# Again, everything went smooth!
#
# ![Transaction](images/transaction.png)

# %% [markdown]
# ## How to listen to those messages?
#
# If you install Django Stomp within your Django App, you'll have a nice Django command that will allow you to set a callback to process the messages from a queue.
#
# Your callback **must** have the following signature:
#
# ```python
# from django_stomp.services.consumer import Payload
#
# def callback(payload: Payload):
#     ...
# ```
#
# In the `Payload`, you'll have:
#
# ```python
# class Payload:
#     ack: Callable # To acknowledge
#     nack: Callable # To not acknowledge
#     headers: Dict # The message headers
#     body: Dict # The message body
# ```
#
# Now, suppose that your queue name is `/queue/xpto` and your callback is inside the module `callback.method`. To start your consumer, you have to run:
#
# ```sh
# python manage.py pubsub /queue/xpto callback.method
# ```

# %% [markdown]
# For example only, we will use the following callback:
#
# ```python
# import logging
#
# from django_stomp.services.consumer import Payload
#
# logger = logging.getLogger(__name__)
#
# def ack_callback(payload: Payload):
#     """
#     Acknoweledge that the message was received, informing the broker that it can
#     remove the message from queue.
#     """
#     logger.info(payload)
#     payload.ack()
# ```
#
# And, start the consumer inside Python code:

# %%
from django.core.management import call_command
from concurrent.futures import ThreadPoolExecutor

pool_executor = ThreadPoolExecutor()

callback_str = "examples.examples.ack_callback"
queue_name = "/queue/xpto"

pool_executor.submit(call_command, "pubsub", queue_name, callback_str)
# Out:
# <Future at 0x1050a51f0 state=running>

# %% [markdown]
# And the message was consumed!
#
# ![Message consumed](images/message-consumed.png)

# %% [markdown]
# ## Virtual Topics?
#
# What if you want to publish the same message to multiple queues? [Virtual Topics](https://activemq.apache.org/virtual-destinations.html) to the rescue! It's a concept we bring from ActiveMQ and it works as the following:
#
# - Consume the message from `Consumer.app-name.VirtualTopic.topic-name` (it **must** follow this pattern `Consumer.*.VirtualTopic.*`)
# - Publish a message to `/topic/VirtualTopic.topic-name` (it **must** follow this initial pattern `/topic/VirtualTopic.*`)
#
# ![Virtual Topics](images/virtual-topics.png)
#
# It's important to mention that the queue from a consumer will only start to receive published messages after it's initial setup (after a consumer is setup). Any message published before won't be received.
#
# Let's try to setup 2 consumers from the topic `/topic/VirtualTopic.xpto`

# %%
from django.core.management import call_command
from concurrent.futures import ThreadPoolExecutor

pool_executor = ThreadPoolExecutor()

callback_str = "examples.examples.ack_callback"
queue_name_from_consumer_A = "Consumer.app-A.VirtualTopic.xpto"
queue_name_from_consumer_B = "Consumer.app-B.VirtualTopic.xpto"

pool_executor.submit(call_command, "pubsub", queue_name_from_consumer_A, callback_str)
pool_executor.submit(call_command, "pubsub", queue_name_from_consumer_B, callback_str)
# Out:
# <Future at 0x1050c3430 state=running>

# %% [markdown]
# And, we have the two new queues
#
# ![Virtual Topic Consumers](images/topic-consumers.png)
# ![Consumer A](images/consumer-a.png)
# ![Consumer B](images/consumer-b.png)
#
# And, we can now send a message to `/topic/VirtualTopic.xpto` and the two consumers will receive the same message!

# %%
import uuid
from django_stomp.builder import build_publisher

publisher = build_publisher(f"publisher-{uuid.uuid4()}")

destination_name = "/topic/VirtualTopic.xpto"
message_to_publish = {
    "key": "value"
}
with publisher.auto_open_close_connection():
    publisher.send(message_to_publish, destination_name)
# Out:
# INFO     [2021-02-19 21:25:01,199] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-90af70f8-cbf9-4f1a-b152-c1f5cdd6cdd2'}
# INFO     [2021-02-19 21:25:01,212] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:25:01,213] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:01,213] [MainThread] django_stomp: It is not open. Starting...
# INFO     [2021-02-19 21:25:01,219] [ThreadPoolExecutor-1_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,221] [ThreadPoolExecutor-1_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,225] [ThreadPoolExecutor-1_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,223] [ThreadPoolExecutor-2_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,225] [ThreadPoolExecutor-2_1] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,227] [ThreadPoolExecutor-1_0] django_stomp: Starting listener with name: a14051a9-c18a-4b00-a3f1-3f732947c392
# INFO     [2021-02-19 21:25:01,228] [ThreadPoolExecutor-2_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,233] [ThreadPoolExecutor-2_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,231] [ThreadPoolExecutor-1_0] django_stomp: Subscribe/Listener auto-generated ID: dcac93b7-fbb9-46b1-b300-d78fd1540744-listener
# INFO     [2021-02-19 21:25:01,229] [ThreadPoolExecutor-2_1] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,239] [ThreadPoolExecutor-2_0] django_stomp: Starting listener with name: 68f5d1c0-ed79-4112-87ec-cee9f541b1ab
# INFO     [2021-02-19 21:25:01,241] [ThreadPoolExecutor-1_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,242] [ThreadPoolExecutor-2_1] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,245] [ThreadPoolExecutor-2_0] django_stomp: Subscribe/Listener auto-generated ID: 64330609-d7dd-4984-8e88-24c2cd032086-listener
# INFO     [2021-02-19 21:25:01,246] [ThreadPoolExecutor-1_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,248] [ThreadPoolExecutor-2_1] django_stomp: Starting listener with name: 231de182-ef07-4ce9-bf5e-e1c5c0107c75
# INFO     [2021-02-19 21:25:01,249] [ThreadPoolExecutor-2_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,252] [ThreadPoolExecutor-2_1] django_stomp: Subscribe/Listener auto-generated ID: bf2ff989-902e-45e6-8876-6673b121f8e7-listener
# INFO     [2021-02-19 21:25:01,253] [ThreadPoolExecutor-1_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,254] [ThreadPoolExecutor-2_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,255] [ThreadPoolExecutor-2_1] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,256] [Thread-6] stomp.py: Starting receiver loop (<Thread(Thread-6, started daemon 123145599516672)>)
# INFO     [2021-02-19 21:25:01,257] [ThreadPoolExecutor-1_0] stomp.py: Created thread <Thread(Thread-6, started daemon 123145599516672)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,259] [ThreadPoolExecutor-2_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,259] [ThreadPoolExecutor-2_1] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,262] [ThreadPoolExecutor-1_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,264] [Thread-7] stomp.py: Starting receiver loop (<Thread(Thread-7, started daemon 123145616306176)>)
# INFO     [2021-02-19 21:25:01,264] [ThreadPoolExecutor-2_0] stomp.py: Created thread <Thread(Thread-7, started daemon 123145616306176)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,272] [ThreadPoolExecutor-2_1] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,276] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,277] [Thread-8] stomp.py: Starting receiver loop (<Thread(Thread-8, started daemon 123145633095680)>)
# INFO     [2021-02-19 21:25:01,278] [ThreadPoolExecutor-2_1] stomp.py: Created thread <Thread(Thread-8, started daemon 123145633095680)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,280] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,390] [Thread-7] stomp.py: Received frame: 'CONNECTED', len(body)=0
# Provided parameters: {'verbosity': 1, 'settings': None, 'pythonpath': None, 'traceback': False, 'no_color': False, 'force_color': False, 'skip_checks': True, 'source_destination': '/queue/xpto', 'callback_function': 'examples.examples.ack_callback'}
# Calling internal service to consume messages
# Provided parameters: {'verbosity': 1, 'settings': None, 'pythonpath': None, 'traceback': False, 'no_color': False, 'force_color': False, 'skip_checks': True, 'source_destination': 'Consumer.app-A.VirtualTopic.xpto', 'callback_function': 'examples.examples.ack_callback'}
# Calling internal service to consume messages
# Provided parameters: {'verbosity': 1, 'settings': None, 'pythonpath': None, 'traceback': False, 'no_color': False, 'force_color': False, 'skip_checks': True, 'source_destination': 'Consumer.app-B.VirtualTopic.xpto', 'callback_function': 'examples.examples.ack_callback'}
# Calling internal service to consume messages
# INFO     [2021-02-19 21:25:01,390] [Thread-6] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,427] [Thread-8] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,428] [Thread-9] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:01,429] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:01,448] [Thread-10] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:01,449] [ThreadPoolExecutor-1_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:01,458] [Thread-11] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:01,459] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:01,477] [ThreadPoolExecutor-2_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,490] [ThreadPoolExecutor-1_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,513] [ThreadPoolExecutor-1_0] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:01,499] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:01,494] [ThreadPoolExecutor-2_1] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,522] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:01,541] [Thread-7] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:01,554] [Thread-7] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:01,554] [StompHeartbeatThread-9] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:01,554] [ThreadPoolExecutor-2_0] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:01,556] [Thread-6] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:01,579] [ThreadPoolExecutor-2_0] django_stomp: Created/Refreshed DLQ in case of RabbitMQ...
# INFO     [2021-02-19 21:25:01,589] [Thread-8] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:01,590] [Thread-6] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:01,590] [StompHeartbeatThread-10] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:01,590] [ThreadPoolExecutor-1_0] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:01,591] [ThreadPoolExecutor-2_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,594] [Thread-8] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:01,594] [StompHeartbeatThread-11] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:01,594] [ThreadPoolExecutor-2_1] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:01,610] [ThreadPoolExecutor-1_0] django_stomp: Created/Refreshed DLQ in case of RabbitMQ...
# INFO     [2021-02-19 21:25:01,613] [ThreadPoolExecutor-2_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,625] [ThreadPoolExecutor-2_1] django_stomp: Created/Refreshed DLQ in case of RabbitMQ...
# INFO     [2021-02-19 21:25:01,629] [ThreadPoolExecutor-1_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,635] [ThreadPoolExecutor-2_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,641] [ThreadPoolExecutor-2_1] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:01,645] [ThreadPoolExecutor-1_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,651] [ThreadPoolExecutor-2_0] django_stomp: Starting listener with name: 6dcc9a19-e76a-4b8a-ab58-dc1615cc763d
# INFO     [2021-02-19 21:25:01,653] [ThreadPoolExecutor-2_1] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:01,659] [ThreadPoolExecutor-1_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,676] [ThreadPoolExecutor-2_0] django_stomp: Subscribe/Listener auto-generated ID: c9cfeff9-5ef1-47c7-9169-c45f598db749-listener
# INFO     [2021-02-19 21:25:01,679] [ThreadPoolExecutor-2_1] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:01,680] [ThreadPoolExecutor-1_0] django_stomp: Starting listener...
# INFO     [2021-02-19 21:25:01,682] [ThreadPoolExecutor-2_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,685] [ThreadPoolExecutor-2_1] django_stomp: Starting listener with name: f9987680-b5b7-4510-bd6b-348898d82e53
# INFO     [2021-02-19 21:25:01,689] [ThreadPoolExecutor-1_0] django_stomp: Starting listener with name: d186ef7e-f73d-4c1e-bd0e-01b2e93ca0a5
# INFO     [2021-02-19 21:25:01,717] [MainThread] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,717] [ThreadPoolExecutor-2_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,726] [ThreadPoolExecutor-2_1] django_stomp: Subscribe/Listener auto-generated ID: 933cbcfa-1fa0-4600-9702-693eb276e67f-listener
# INFO     [2021-02-19 21:25:01,728] [ThreadPoolExecutor-1_0] django_stomp: Subscribe/Listener auto-generated ID: 6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener
# INFO     [2021-02-19 21:25:01,738] [MainThread] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,742] [ThreadPoolExecutor-2_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,743] [ThreadPoolExecutor-2_1] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,745] [ThreadPoolExecutor-1_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:01,757] [MainThread] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,758] [Thread-12] stomp.py: Starting receiver loop (<Thread(Thread-12, started daemon 123145599516672)>)
# INFO     [2021-02-19 21:25:01,758] [ThreadPoolExecutor-2_0] stomp.py: Created thread <Thread(Thread-12, started daemon 123145599516672)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,760] [ThreadPoolExecutor-2_1] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,763] [ThreadPoolExecutor-1_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,773] [Thread-13] stomp.py: Starting receiver loop (<Thread(Thread-13, started daemon 123145616306176)>)
# INFO     [2021-02-19 21:25:01,774] [MainThread] stomp.py: Created thread <Thread(Thread-13, started daemon 123145616306176)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,776] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,780] [ThreadPoolExecutor-2_1] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,780] [ThreadPoolExecutor-1_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:01,784] [MainThread] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,788] [Thread-14] stomp.py: Starting receiver loop (<Thread(Thread-14, started daemon 123145633095680)>)
# INFO     [2021-02-19 21:25:01,788] [ThreadPoolExecutor-2_1] stomp.py: Created thread <Thread(Thread-14, started daemon 123145633095680)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,790] [Thread-15] stomp.py: Starting receiver loop (<Thread(Thread-15, started daemon 123145649885184)>)
# INFO     [2021-02-19 21:25:01,790] [ThreadPoolExecutor-1_0] stomp.py: Created thread <Thread(Thread-15, started daemon 123145649885184)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:01,798] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,808] [ThreadPoolExecutor-1_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:01,970] [Thread-14] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,972] [Thread-16] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:01,973] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:01,975] [Thread-12] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,976] [Thread-13] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,977] [ThreadPoolExecutor-2_1] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,980] [Thread-17] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:01,980] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:01,982] [MainThread] django_stomp: Connected
# INFO     [2021-02-19 21:25:01,985] [Thread-15] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:01,987] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:01,990] [ThreadPoolExecutor-2_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:02,000] [Thread-18] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:02,001] [ThreadPoolExecutor-1_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:02,007] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:02,008] [Thread-14] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:02,010] [ThreadPoolExecutor-1_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:02,014] [Thread-14] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:02,014] [ThreadPoolExecutor-2_1] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:02,015] [StompHeartbeatThread-16] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:02,020] [ThreadPoolExecutor-2_1] django_stomp: Created/Refreshed queue to consume from topic in case of RabbitMQ...
# INFO     [2021-02-19 21:25:02,024] [ThreadPoolExecutor-2_1] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:02,022] [Thread-15] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:02,028] [Thread-15] django_stomp: Message ID: T_6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener@@session-Bhycp-D5JjsHK35G39n9uQ@@1
# INFO     [2021-02-19 21:25:02,026] [ThreadPoolExecutor-2_1] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:02,025] [Thread-12] stomp.py: Received frame: 'RECEIPT', len(body)=0
# DEBUG    [2021-02-19 21:25:02,037] [Thread-15] django_stomp: Received headers: {'subscription': '6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener', 'destination': '/queue/xpto', 'message-id': 'T_6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener@@session-Bhycp-D5JjsHK35G39n9uQ@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/xpto', 'correlation-id': '009e81b7-4227-451a-98ac-2763a10b6af8', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# INFO     [2021-02-19 21:25:02,038] [ThreadPoolExecutor-2_1] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:02,040] [Thread-12] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:02,040] [StompHeartbeatThread-17] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:02,040] [ThreadPoolExecutor-2_0] django_stomp: Disconnected
# DEBUG    [2021-02-19 21:25:02,042] [Thread-15] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:02,044] [ThreadPoolExecutor-2_1] django_stomp: Starting listener...
# INFO     [2021-02-19 21:25:02,049] [ThreadPoolExecutor-2_0] django_stomp: Created/Refreshed queue to consume from topic in case of RabbitMQ...
# INFO     [2021-02-19 21:25:02,052] [6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener_0] examples.examples: Payload(ack=<function Listener.on_message.<locals>.ack_logic at 0x1051a4b80>, nack=<function Listener.on_message.<locals>.nack_logic at 0x1051c2790>, headers={'subscription': '6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener', 'destination': '/queue/xpto', 'message-id': 'T_6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener@@session-Bhycp-D5JjsHK35G39n9uQ@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/xpto', 'correlation-id': '009e81b7-4227-451a-98ac-2763a10b6af8', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}, body={'key': 'value'})
# INFO     [2021-02-19 21:25:02,055] [ThreadPoolExecutor-2_1] django_stomp: Starting listener with name: 05f25517-ae1f-4211-afad-735974d6d2af
# INFO     [2021-02-19 21:25:02,058] [ThreadPoolExecutor-2_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:02,060] [6da8b1fa-37bb-4183-ae6e-065d17eca5bb-listener_0] stomp.py: Sending frame: 'ACK'
# INFO     [2021-02-19 21:25:02,063] [ThreadPoolExecutor-2_1] django_stomp: Subscribe/Listener auto-generated ID: 24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener
# INFO     [2021-02-19 21:25:02,079] [ThreadPoolExecutor-2_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:02,091] [ThreadPoolExecutor-2_1] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:02,094] [ThreadPoolExecutor-2_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:02,100] [ThreadPoolExecutor-2_1] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,103] [ThreadPoolExecutor-2_0] django_stomp: Starting listener...
# INFO     [2021-02-19 21:25:02,109] [ThreadPoolExecutor-2_1] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,109] [ThreadPoolExecutor-2_0] django_stomp: Starting listener with name: 04f050f5-5a88-4cbe-aeca-b5f94162c560
# INFO     [2021-02-19 21:25:02,112] [Thread-19] stomp.py: Starting receiver loop (<Thread(Thread-19, started daemon 123145633095680)>)
# INFO     [2021-02-19 21:25:02,112] [ThreadPoolExecutor-2_1] stomp.py: Created thread <Thread(Thread-19, started daemon 123145633095680)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:02,113] [ThreadPoolExecutor-2_0] django_stomp: Subscribe/Listener auto-generated ID: 891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener
# INFO     [2021-02-19 21:25:02,120] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:02,122] [ThreadPoolExecutor-2_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:02,126] [ThreadPoolExecutor-2_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,135] [ThreadPoolExecutor-2_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,138] [Thread-20] stomp.py: Starting receiver loop (<Thread(Thread-20, started daemon 123145666674688)>)
# INFO     [2021-02-19 21:25:02,138] [ThreadPoolExecutor-2_0] stomp.py: Created thread <Thread(Thread-20, started daemon 123145666674688)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:02,142] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:02,156] [Thread-19] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:02,158] [ThreadPoolExecutor-2_1] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:02,158] [Thread-21] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:02,164] [ThreadPoolExecutor-2_1] django_stomp: Connected
# INFO     [2021-02-19 21:25:02,190] [Thread-20] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:02,196] [Thread-22] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:02,197] [ThreadPoolExecutor-2_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:02,202] [ThreadPoolExecutor-2_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:02,496] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:02,505] [MainThread] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:02,513] [Thread-20] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:02,513] [Thread-19] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:02,518] [Thread-20] django_stomp: Message ID: T_891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener@@session-7wF2g6CBJiVicj1snQTVXw@@1
# INFO     [2021-02-19 21:25:02,518] [Thread-13] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:02,524] [Thread-19] django_stomp: Message ID: T_24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener@@session-A_dUHpvW7VQRsRTQIkZFbg@@1
# DEBUG    [2021-02-19 21:25:02,525] [Thread-20] django_stomp: Received headers: {'subscription': '891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener', 'destination': '/topic/VirtualTopic.xpto', 'message-id': 'T_891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener@@session-7wF2g6CBJiVicj1snQTVXw@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.VirtualTopic.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/topic/VirtualTopic.xpto', 'correlation-id': 'bc794a71-72e9-4508-8214-6ed286bdd74e', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# INFO     [2021-02-19 21:25:02,527] [Thread-13] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:02,527] [MainThread] django_stomp: Disconnected
# DEBUG    [2021-02-19 21:25:02,547] [Thread-19] django_stomp: Received headers: {'subscription': '24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener', 'destination': '/topic/VirtualTopic.xpto', 'message-id': 'T_24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener@@session-A_dUHpvW7VQRsRTQIkZFbg@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.VirtualTopic.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/topic/VirtualTopic.xpto', 'correlation-id': 'bc794a71-72e9-4508-8214-6ed286bdd74e', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# DEBUG    [2021-02-19 21:25:02,548] [Thread-20] django_stomp: Received message: {"key": "value"}
# DEBUG    [2021-02-19 21:25:02,556] [Thread-19] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:02,566] [891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener_0] examples.examples: Payload(ack=<function Listener.on_message.<locals>.ack_logic at 0x1051a44c0>, nack=<function Listener.on_message.<locals>.nack_logic at 0x1050b05e0>, headers={'subscription': '891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener', 'destination': '/topic/VirtualTopic.xpto', 'message-id': 'T_891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener@@session-7wF2g6CBJiVicj1snQTVXw@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.VirtualTopic.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/topic/VirtualTopic.xpto', 'correlation-id': 'bc794a71-72e9-4508-8214-6ed286bdd74e', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}, body={'key': 'value'})

# %% [markdown]
# ![Consumer A process message](images/consumed-a.png)
# ![Consumer B process message](images/consumed-b.png)

# %% [markdown]
# ## What happen if my callback call `nack` instead of `ack`?
#
# That's a good question and it's better represented with an example! Let's say that your callback do the following:
#
# ```python
# import logging
#
# from django_stomp.services.consumer import Payload
#
# logger = logging.getLogger(__name__)
#
#
# def nack_callback(payload: Payload):
#     logger.info(payload)
#     payload.nack()
# ```
#
# And time to see it working:

# %%
import uuid
from django.core.management import call_command
from concurrent.futures import ThreadPoolExecutor
from django_stomp.builder import build_publisher

publisher = build_publisher(f"publisher-{uuid.uuid4()}")

pool_executor = ThreadPoolExecutor()

callback_str = "examples.examples.nack_callback"
queue_name = "/queue/nack-queue"

pool_executor.submit(call_command, "pubsub", queue_name, callback_str)

message = {
    "key": "value"
}
headers = {
    "header-key": "header-value"
}

with build_publisher(f"publisher-{uuid.uuid4()}").auto_open_close_connection() as publisher:
    publisher.send(message, queue_name, headers=headers)
# Out:
# INFO     [2021-02-19 21:25:02,577] [24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener_0] examples.examples: Payload(ack=<function Listener.on_message.<locals>.ack_logic at 0x1051c28b0>, nack=<function Listener.on_message.<locals>.nack_logic at 0x1051c2160>, headers={'subscription': '24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener', 'destination': '/topic/VirtualTopic.xpto', 'message-id': 'T_24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener@@session-A_dUHpvW7VQRsRTQIkZFbg@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.VirtualTopic.xpto', 'x-dead-letter-exchange': '', 'tshoot-destination': '/topic/VirtualTopic.xpto', 'correlation-id': 'bc794a71-72e9-4508-8214-6ed286bdd74e', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}, body={'key': 'value'})
# INFO     [2021-02-19 21:25:02,578] [891f5b60-6105-4e2e-8587-e8e3020dc4ed-listener_0] stomp.py: Sending frame: 'ACK'
# INFO     [2021-02-19 21:25:02,586] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-bfb95579-8908-48fe-bed7-bf6af8d608c8'}
# INFO     [2021-02-19 21:25:02,588] [24d27ce4-dbe6-4046-95d4-78fe6f3fa5e6-listener_0] stomp.py: Sending frame: 'ACK'
# INFO     [2021-02-19 21:25:02,592] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:25:02,601] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:02,609] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-acf02c13-5ebc-45f9-9537-a51b12ad99bd'}
# INFO     [2021-02-19 21:25:02,611] [ThreadPoolExecutor-3_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:02,612] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:25:02,613] [ThreadPoolExecutor-3_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:02,615] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:02,617] [ThreadPoolExecutor-3_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:02,619] [MainThread] django_stomp: It is not open. Starting...
# INFO     [2021-02-19 21:25:02,621] [ThreadPoolExecutor-3_0] django_stomp: Starting listener with name: 31275f88-e55d-4f60-820d-b06715f9d90d
# INFO     [2021-02-19 21:25:02,626] [ThreadPoolExecutor-3_0] django_stomp: Subscribe/Listener auto-generated ID: ab64a263-1b3c-4af0-8d01-a7974504f7d9-listener
# INFO     [2021-02-19 21:25:02,628] [ThreadPoolExecutor-3_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:02,631] [ThreadPoolExecutor-3_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,639] [ThreadPoolExecutor-3_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,640] [Thread-23] stomp.py: Starting receiver loop (<Thread(Thread-23, started daemon 123145767411712)>)
# INFO     [2021-02-19 21:25:02,641] [ThreadPoolExecutor-3_0] stomp.py: Created thread <Thread(Thread-23, started daemon 123145767411712)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:02,645] [ThreadPoolExecutor-3_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:02,657] [Thread-23] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:02,661] [Thread-24] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:02,661] [ThreadPoolExecutor-3_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:02,669] [ThreadPoolExecutor-3_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:02,671] [ThreadPoolExecutor-3_0] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:02,674] [Thread-23] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:02,681] [Thread-23] django_stomp: Message ID: T_ab64a263-1b3c-4af0-8d01-a7974504f7d9-listener@@session-YaND32PODyqdVWyt--F5kw@@1
# DEBUG    [2021-02-19 21:25:02,688] [Thread-23] django_stomp: Received headers: {'subscription': 'ab64a263-1b3c-4af0-8d01-a7974504f7d9-listener', 'destination': '/queue/DLQ.nack-queue', 'message-id': 'T_ab64a263-1b3c-4af0-8d01-a7974504f7d9-listener@@session-YaND32PODyqdVWyt--F5kw@@1', 'redelivered': 'true', 'header-key': 'header-value', 'tshoot-destination': '/queue/nack-queue', 'x-dead-letter-exchange': '', 'x-dead-letter-routing-key': 'DLQ.nack-queue', 'x-first-death-exchange': '', 'x-first-death-queue': 'nack-queue', 'x-first-death-reason': 'rejected', 'correlation-id': '0bb1e8e5-b93a-4890-8742-12d3e99b4d22', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# DEBUG    [2021-02-19 21:25:02,692] [Thread-23] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:02,702] [Thread-23] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:02,707] [Thread-23] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:02,707] [ThreadPoolExecutor-3_0] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:02,707] [StompHeartbeatThread-24] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:02,710] [ThreadPoolExecutor-3_0] django_stomp: Created/Refreshed DLQ in case of RabbitMQ...
# INFO     [2021-02-19 21:25:02,714] [ThreadPoolExecutor-3_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:02,715] [ThreadPoolExecutor-3_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:02,717] [ThreadPoolExecutor-3_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:02,719] [ThreadPoolExecutor-3_0] django_stomp: Starting listener...
# INFO     [2021-02-19 21:25:02,721] [ThreadPoolExecutor-3_0] django_stomp: Starting listener with name: 8eded2c2-0cde-4402-8d71-e386f082bfbc
# INFO     [2021-02-19 21:25:02,723] [ThreadPoolExecutor-3_0] django_stomp: Subscribe/Listener auto-generated ID: 3727eb1d-34a0-4fa4-98f0-54c22c908409-listener
# INFO     [2021-02-19 21:25:02,725] [ThreadPoolExecutor-3_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:02,726] [ThreadPoolExecutor-3_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,729] [ThreadPoolExecutor-3_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:02,732] [Thread-25] stomp.py: Starting receiver loop (<Thread(Thread-25, started daemon 123145767411712)>)
# INFO     [2021-02-19 21:25:02,732] [ThreadPoolExecutor-3_0] stomp.py: Created thread <Thread(Thread-25, started daemon 123145767411712)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:02,737] [ThreadPoolExecutor-3_0] stomp.py: Sending frame: 'STOMP'
# Provided parameters: {'verbosity': 1, 'settings': None, 'pythonpath': None, 'traceback': False, 'no_color': False, 'force_color': False, 'skip_checks': True, 'source_destination': '/queue/nack-queue', 'callback_function': 'examples.examples.nack_callback'}
# Calling internal service to consume messages
# INFO     [2021-02-19 21:25:02,829] [Thread-25] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:02,834] [Thread-26] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:02,835] [ThreadPoolExecutor-3_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:02,840] [ThreadPoolExecutor-3_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:03,145] [MainThread] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:03,148] [MainThread] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,153] [MainThread] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,155] [Thread-27] stomp.py: Starting receiver loop (<Thread(Thread-27, started daemon 123145817780224)>)
# INFO     [2021-02-19 21:25:03,156] [MainThread] stomp.py: Created thread <Thread(Thread-27, started daemon 123145817780224)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:03,164] [MainThread] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:03,189] [Thread-27] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:03,191] [MainThread] django_stomp: Connected
# INFO     [2021-02-19 21:25:03,704] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:03,705] [MainThread] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:03,748] [Thread-27] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:03,749] [Thread-27] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:03,749] [MainThread] django_stomp: Disconnected

# %% [markdown]
# It was sent to a new queue named as `DLQ.nack-queue`! That behaviour allow us to analyze the received message and if we need, to process it later.
#
# ![NACK queue](images/nack.png)
# ![NACK DLQ queue](images/nack-dlq.png)
# ![NACK DLQ message](images/nack-message.png)

# %% [markdown]
# ## What happen if my callback raise an exception?
#
# Again, let's try to see it with an example:
#
# ```python
# import logging
#
# from django_stomp.services.consumer import Payload
#
# logger = logging.getLogger(__name__)
#
#
# def exception_callback(payload: Payload):
#     logger.info(payload)
#     raise Exception("Won't process!")
# ```

# %%
import uuid
from django.core.management import call_command
from concurrent.futures import ThreadPoolExecutor
from django_stomp.builder import build_publisher

publisher = build_publisher(f"publisher-{uuid.uuid4()}")

pool_executor = ThreadPoolExecutor()

callback_str = "examples.examples.exception_callback"
queue_name = "/queue/exception-queue"

pool_executor.submit(call_command, "pubsub", queue_name, callback_str)

message = {
    "key": "value"
}
headers = {
    "header-key": "header-value"
}

with build_publisher(f"publisher-{uuid.uuid4()}").auto_open_close_connection() as publisher:
    publisher.send(message, queue_name, headers=headers)
# Out:
# INFO     [2021-02-19 21:25:03,763] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-57e6388d-38e1-4429-8ad9-c277c5c5295c'}
# INFO     [2021-02-19 21:25:03,764] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:25:03,765] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:03,770] [MainThread] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': 'publisher-2ff83b6b-03b4-48d8-b526-dc4a92395f13'}
# INFO     [2021-02-19 21:25:03,772] [MainThread] django_stomp: Building publisher...
# INFO     [2021-02-19 21:25:03,773] [MainThread] django_stomp: Use SSL? False. Version: 2
# INFO     [2021-02-19 21:25:03,774] [MainThread] django_stomp: It is not open. Starting...
# INFO     [2021-02-19 21:25:03,775] [ThreadPoolExecutor-4_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:03,777] [ThreadPoolExecutor-4_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:03,778] [ThreadPoolExecutor-4_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:03,779] [ThreadPoolExecutor-4_0] django_stomp: Starting listener with name: 05c4ce3b-ee1e-4480-9b3b-c74091ef9ebd
# INFO     [2021-02-19 21:25:03,780] [ThreadPoolExecutor-4_0] django_stomp: Subscribe/Listener auto-generated ID: 027938e6-b3a7-4955-8a80-4ad51d97bd90-listener
# INFO     [2021-02-19 21:25:03,781] [ThreadPoolExecutor-4_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:03,782] [ThreadPoolExecutor-4_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,784] [ThreadPoolExecutor-4_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,786] [Thread-28] stomp.py: Starting receiver loop (<Thread(Thread-28, started daemon 123145834569728)>)
# INFO     [2021-02-19 21:25:03,786] [ThreadPoolExecutor-4_0] stomp.py: Created thread <Thread(Thread-28, started daemon 123145834569728)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:03,794] [ThreadPoolExecutor-4_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:03,836] [Thread-25] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:03,838] [Thread-25] django_stomp: Message ID: T_3727eb1d-34a0-4fa4-98f0-54c22c908409-listener@@session-7BYk-1VtmIFlPxbgC2t3Ww@@1
# DEBUG    [2021-02-19 21:25:03,841] [Thread-25] django_stomp: Received headers: {'subscription': '3727eb1d-34a0-4fa4-98f0-54c22c908409-listener', 'destination': '/queue/nack-queue', 'message-id': 'T_3727eb1d-34a0-4fa4-98f0-54c22c908409-listener@@session-7BYk-1VtmIFlPxbgC2t3Ww@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.nack-queue', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/nack-queue', 'header-key': 'header-value', 'correlation-id': 'bfdfcde5-5591-4e61-8adf-faf1da8b62a2', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# DEBUG    [2021-02-19 21:25:03,844] [Thread-25] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:03,852] [3727eb1d-34a0-4fa4-98f0-54c22c908409-listener_0] examples.examples: Payload(ack=<function Listener.on_message.<locals>.ack_logic at 0x1051df940>, nack=<function Listener.on_message.<locals>.nack_logic at 0x1051df5e0>, headers={'subscription': '3727eb1d-34a0-4fa4-98f0-54c22c908409-listener', 'destination': '/queue/nack-queue', 'message-id': 'T_3727eb1d-34a0-4fa4-98f0-54c22c908409-listener@@session-7BYk-1VtmIFlPxbgC2t3Ww@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.nack-queue', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/nack-queue', 'header-key': 'header-value', 'correlation-id': 'bfdfcde5-5591-4e61-8adf-faf1da8b62a2', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}, body={'key': 'value'})
# INFO     [2021-02-19 21:25:03,854] [Thread-28] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:03,855] [3727eb1d-34a0-4fa4-98f0-54c22c908409-listener_0] stomp.py: Sending frame: 'NACK'
# INFO     [2021-02-19 21:25:03,857] [Thread-29] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:03,858] [ThreadPoolExecutor-4_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:03,871] [ThreadPoolExecutor-4_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:03,873] [ThreadPoolExecutor-4_0] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:03,883] [Thread-28] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:03,889] [Thread-28] django_stomp: Message ID: T_027938e6-b3a7-4955-8a80-4ad51d97bd90-listener@@session-S4Exci6abPcMGEd3xH_H7g@@1
# DEBUG    [2021-02-19 21:25:03,894] [Thread-28] django_stomp: Received headers: {'subscription': '027938e6-b3a7-4955-8a80-4ad51d97bd90-listener', 'destination': '/queue/DLQ.exception-queue', 'message-id': 'T_027938e6-b3a7-4955-8a80-4ad51d97bd90-listener@@session-S4Exci6abPcMGEd3xH_H7g@@1', 'redelivered': 'true', 'header-key': 'header-value', 'tshoot-destination': '/queue/exception-queue', 'x-dead-letter-exchange': '', 'x-dead-letter-routing-key': 'DLQ.exception-queue', 'x-first-death-exchange': '', 'x-first-death-queue': 'exception-queue', 'x-first-death-reason': 'rejected', 'correlation-id': '2be0cde7-bf30-4b91-ae20-cfd64df93807', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# DEBUG    [2021-02-19 21:25:03,908] [Thread-28] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:03,910] [Thread-28] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:03,912] [Thread-28] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:03,913] [StompHeartbeatThread-29] stomp.py: Heartbeat loop ended
# INFO     [2021-02-19 21:25:03,913] [ThreadPoolExecutor-4_0] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:03,918] [ThreadPoolExecutor-4_0] django_stomp: Created/Refreshed DLQ in case of RabbitMQ...
# INFO     [2021-02-19 21:25:03,922] [ThreadPoolExecutor-4_0] django_stomp: Server details connection: {'host': 'localhost', 'port': 61613, 'hostStandby': None, 'portStandby': None, 'outgoingHeartbeat': 10000, 'incomingHeartbeat': 10000, 'subscriptionId': None, 'vhost': None}. Extra params: {'use_ssl': False, 'client_id': None}
# INFO     [2021-02-19 21:25:03,930] [ThreadPoolExecutor-4_0] django_stomp: Building listener...
# INFO     [2021-02-19 21:25:03,931] [ThreadPoolExecutor-4_0] django_stomp: Use SSL? False. Version: 2. Outgoing/Ingoing heartbeat: 10000/10000. Background? True
# INFO     [2021-02-19 21:25:03,932] [ThreadPoolExecutor-4_0] django_stomp: Starting listener...
# INFO     [2021-02-19 21:25:03,934] [ThreadPoolExecutor-4_0] django_stomp: Starting listener with name: c6665c07-15dc-4100-b745-c3620c55fa4b
# INFO     [2021-02-19 21:25:03,936] [ThreadPoolExecutor-4_0] django_stomp: Subscribe/Listener auto-generated ID: 546f887d-03f7-4dab-9f7c-df4eb84027bb-listener
# INFO     [2021-02-19 21:25:03,938] [ThreadPoolExecutor-4_0] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:03,940] [ThreadPoolExecutor-4_0] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,944] [ThreadPoolExecutor-4_0] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:03,979] [Thread-30] stomp.py: Starting receiver loop (<Thread(Thread-30, started daemon 123145834569728)>)
# Provided parameters: {'verbosity': 1, 'settings': None, 'pythonpath': None, 'traceback': False, 'no_color': False, 'force_color': False, 'skip_checks': True, 'source_destination': '/queue/exception-queue', 'callback_function': 'examples.examples.exception_callback'}
# Calling internal service to consume messages
# INFO     [2021-02-19 21:25:03,980] [ThreadPoolExecutor-4_0] stomp.py: Created thread <Thread(Thread-30, started daemon 123145834569728)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:04,007] [ThreadPoolExecutor-4_0] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:04,092] [Thread-30] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:04,109] [Thread-31] stomp.py: Starting heartbeat loop
# INFO     [2021-02-19 21:25:04,110] [ThreadPoolExecutor-4_0] stomp.py: Sending frame: 'SUBSCRIBE'
# INFO     [2021-02-19 21:25:04,114] [ThreadPoolExecutor-4_0] django_stomp: Connected
# INFO     [2021-02-19 21:25:04,278] [MainThread] stomp.py: attempt reconnection (True, None, 0)
# INFO     [2021-02-19 21:25:04,281] [MainThread] stomp.py: Attempting connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:04,284] [MainThread] stomp.py: Established connection to host localhost, port 61613
# INFO     [2021-02-19 21:25:04,287] [Thread-32] stomp.py: Starting receiver loop (<Thread(Thread-32, started daemon 123145901727744)>)
# INFO     [2021-02-19 21:25:04,287] [MainThread] stomp.py: Created thread <Thread(Thread-32, started daemon 123145901727744)> using func <function default_create_thread at 0x105136e50>
# INFO     [2021-02-19 21:25:04,295] [MainThread] stomp.py: Sending frame: 'STOMP'
# INFO     [2021-02-19 21:25:04,318] [Thread-32] stomp.py: Received frame: 'CONNECTED', len(body)=0
# INFO     [2021-02-19 21:25:04,319] [MainThread] django_stomp: Connected
# INFO     [2021-02-19 21:25:04,825] [MainThread] stomp.py: Sending frame: 'SEND'
# INFO     [2021-02-19 21:25:04,827] [MainThread] stomp.py: Sending frame: 'DISCONNECT'
# INFO     [2021-02-19 21:25:04,835] [Thread-32] stomp.py: Received frame: 'RECEIPT', len(body)=0
# INFO     [2021-02-19 21:25:04,836] [Thread-32] stomp.py: Receiver loop ended
# INFO     [2021-02-19 21:25:04,837] [MainThread] django_stomp: Disconnected
# INFO     [2021-02-19 21:25:04,843] [Thread-30] stomp.py: Received frame: 'MESSAGE', len(body)=16
# INFO     [2021-02-19 21:25:04,845] [Thread-30] django_stomp: Message ID: T_546f887d-03f7-4dab-9f7c-df4eb84027bb-listener@@session-ssa2fxhvS4YLdiDQwewZfA@@1
# DEBUG    [2021-02-19 21:25:04,846] [Thread-30] django_stomp: Received headers: {'subscription': '546f887d-03f7-4dab-9f7c-df4eb84027bb-listener', 'destination': '/queue/exception-queue', 'message-id': 'T_546f887d-03f7-4dab-9f7c-df4eb84027bb-listener@@session-ssa2fxhvS4YLdiDQwewZfA@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.exception-queue', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/exception-queue', 'header-key': 'header-value', 'correlation-id': 'c4e0f2c2-9e2d-461a-91f6-78a3fe218601', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}
# DEBUG    [2021-02-19 21:25:04,847] [Thread-30] django_stomp: Received message: {"key": "value"}
# INFO     [2021-02-19 21:25:04,848] [546f887d-03f7-4dab-9f7c-df4eb84027bb-listener_0] examples.examples: Payload(ack=<function Listener.on_message.<locals>.ack_logic at 0x1051df040>, nack=<function Listener.on_message.<locals>.nack_logic at 0x1051dfb80>, headers={'subscription': '546f887d-03f7-4dab-9f7c-df4eb84027bb-listener', 'destination': '/queue/exception-queue', 'message-id': 'T_546f887d-03f7-4dab-9f7c-df4eb84027bb-listener@@session-ssa2fxhvS4YLdiDQwewZfA@@1', 'redelivered': 'false', 'x-dead-letter-routing-key': 'DLQ.exception-queue', 'x-dead-letter-exchange': '', 'tshoot-destination': '/queue/exception-queue', 'header-key': 'header-value', 'correlation-id': 'c4e0f2c2-9e2d-461a-91f6-78a3fe218601', 'persistent': 'true', 'content-type': 'application/json;charset=utf-8', 'content-length': '16'}, body={'key': 'value'})
# ERROR    [2021-02-19 21:25:04,849] [546f887d-03f7-4dab-9f7c-df4eb84027bb-listener_0] django_stomp: A exception of type <class 'Exception'> was captured during callback logic
# Traceback (most recent call last):
#   File "/Users/fabiokubo/.local/share/virtualenvs/rabbitmq-stomp-mdMSiXPL/lib/python3.9/site-packages/django_stomp/execution.py", line 73, in _callback
#     callback_function(payload)
#   File "/Volumes/Workspace/dev/rabbitmq-stomp/examples/examples.py", line 59, in exception_callback
#     raise Exception("Won't process!")
# Exception: Won't process!
# WARNING  [2021-02-19 21:25:04,852] [546f887d-03f7-4dab-9f7c-df4eb84027bb-listener_0] django_stomp: Trying to do NACK explicitly sending the message to DLQ...
# INFO     [2021-02-19 21:25:04,853] [546f887d-03f7-4dab-9f7c-df4eb84027bb-listener_0] stomp.py: Sending frame: 'NACK'
# WARNING  [2021-02-19 21:25:04,854] [546f887d-03f7-4dab-9f7c-df4eb84027bb-listener_0] django_stomp: Done!
# INFO     [2021-02-19 21:25:06,981] [Thread-15] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:07,154] [Thread-19] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:07,187] [Thread-20] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:07,826] [Thread-25] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:09,086] [Thread-30] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:11,977] [Thread-15] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:12,065] [StompHeartbeatThread-18] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:12,153] [Thread-19] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:12,182] [Thread-20] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:12,582] [StompHeartbeatThread-22] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:12,591] [StompHeartbeatThread-21] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:12,825] [Thread-25] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:13,859] [StompHeartbeatThread-26] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:14,080] [Thread-30] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:14,855] [StompHeartbeatThread-31] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:16,972] [Thread-15] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:17,150] [Thread-19] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:17,176] [Thread-20] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:17,820] [Thread-25] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:19,076] [Thread-30] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:21,968] [Thread-15] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:22,069] [StompHeartbeatThread-18] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:22,144] [Thread-19] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:22,173] [Thread-20] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:22,585] [StompHeartbeatThread-22] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:22,596] [StompHeartbeatThread-21] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:22,814] [Thread-25] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:23,861] [StompHeartbeatThread-26] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:24,071] [Thread-30] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:24,859] [StompHeartbeatThread-31] stomp.py: Sending frame: 'heartbeat'
# INFO     [2021-02-19 21:25:26,979] [Thread-15] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:27,158] [Thread-19] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:27,187] [Thread-20] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:27,844] [Thread-25] stomp.py: Received frame: 'heartbeat', len(body)=0
# INFO     [2021-02-19 21:25:29,097] [Thread-30] stomp.py: Received frame: 'heartbeat', len(body)=0

# %% [markdown]
# Guess what?! Django Stomp will catch the exception and call `nack`, sending our message to the DLQ!
#
# ![Exception Queue](images/exception.png)
# ![Exception DLQ](images/exception-dlq.png)
# ![Exception Message](images/exception-message.png)
# ![Exception Logs](images/exception-log.png)

# %% [markdown]
# # The end
#
# And that concludes our little tutorial on Django Stomp version 4.20.0! I hope that you could understand some of the features it has and if you have any questions or suggestions, feel free to create an issue [here](https://github.com/juntossomosmais/django-stomp/issues)!
#
# Any contributions will be highly appreciated too!
